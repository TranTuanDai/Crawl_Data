# %%
import pandas as pd
from bs4 import BeautifulSoup
import regex as re
import numpy as np

# %%
df_chidinh = pd.read_excel('D:/FRT/5.Python/tac_dung_phu/Thuong_gap_itgap_hiem_gap/Frequent_less_rarely.xlsx')
df_disease = pd.read_excel('D:/FRT/5.Python/tac_dung_phu/Thuong_gap_itgap_hiem_gap/Side_Effect.xlsx')

# %%
df_chidinh.head(10)
# Out:
#    Code  Name     Id  IsActive  IsDisplayUICode  CategoryId  CatName  \
# 0   NaN   NaN  40155       NaN              NaN         NaN      NaN
# 1   NaN   NaN  40157       NaN              NaN         NaN      NaN
# 2   NaN   NaN  40161       NaN              NaN         NaN      NaN
# 3   NaN   NaN  40173       NaN              NaN         NaN      NaN
# 4   NaN   NaN  40175       NaN              NaN         NaN      NaN
# 5   NaN   NaN  40178       NaN              NaN         NaN      NaN
# 6   NaN   NaN  40194       NaN              NaN         NaN      NaN
# 7   NaN   NaN  40218       NaN              NaN         NaN      NaN
# 8   NaN   NaN  40226       NaN              NaN         NaN      NaN
# 9   NaN   NaN  40234       NaN              NaN         NaN      NaN
#
#                                          CustomValue
# 0  Ù tai, giảm thính lực, nhức đầu (khi quá liều)...
# 1  Buồn nôn, nôn, đau bụng, ợ nóng, nổi mề đay, p...
# ...

# %%
df_chidinh
# Out:
#        Code  Name      Id  IsActive  IsDisplayUICode  CategoryId  CatName  \
# 0       NaN   NaN   40155       NaN              NaN         NaN      NaN
# 1       NaN   NaN   40157       NaN              NaN         NaN      NaN
# 2       NaN   NaN   40161       NaN              NaN         NaN      NaN
# 3       NaN   NaN   40173       NaN              NaN         NaN      NaN
# 4       NaN   NaN   40175       NaN              NaN         NaN      NaN
# ...     ...   ...     ...       ...              ...         ...      ...
# 14581   NaN   NaN  83521I       NaN              NaN         NaN      NaN
# 14582   NaN   NaN  83521T       NaN              NaN         NaN      NaN
# 14583   NaN   NaN  84541H       NaN              NaN         NaN      NaN
# 14584   NaN   NaN  84541I       NaN              NaN         NaN      NaN
# 14585   NaN   NaN  84541T       NaN              NaN         NaN      NaN
#
#                                              CustomValue
# ...

# %%
def new_trim_text(txt):
    words_list = txt.split(' ')
    remove_consecutive_space = ' '.join([word for word in words_list if word != ''])
    return remove_consecutive_space

# %%
def html_to_text_clean(txt):
    # remove_html_tags = BeautifulSoup(txt, 'lxml').text
    # replace_non_breaking_space = remove_html_tags.replace('\xa0', ' ')
    # remove_consecutive_space = new_trim_text(replace_non_breaking_space)
    uppercase = txt.upper()
    return uppercase
